# %%
#!pip install pytrends

# %%
# pip install pytrends
import pandas as pd
from pytrends.request import TrendReq
pytrends = TrendReq(hl="en-US", tz=360)

# %%
# trends 
def gtrends_overtime(full_list, key_ref, save_name="", directory="", category=0, time='all', loc=''):
    #iterate every 4 item in list plus a keyword reference as the relative comparison
    i = 0
    while i < len(kw_list):
        l = kw_list[i:(i+4)]
        l.append(key_ref)
        pytrends.build_payload(l, cat=category, timeframe=time, geo=loc, gprop='')
        df_time = pytrends.interest_over_time()
        df_time.reset_index(inplace=True)
        df_time_name = "gtrends_overtime"+str(save_name)+str((i+4)//4)+".csv"
        df_time.to_csv(directory+df_time_name, index = False)
        i += 4

#by region 
def gtrends_region(kw_list, key_ref, save_name="", directory="",
                   category=0, time='all', loc='', res='COUNTRY'):
    #iterate every 4 item in list plus a keyword reference as the relative comparison
    i = 0
    while i < len(kw_list):
        l = kw_list[i:(i+4)]
        l.append(key_ref)
        pytrends.build_payload(l, cat=category, timeframe=time, geo=loc, gprop='')
        # resolution can be set to 'REGION' when loc is set to specific country, e.g. 'US'
        df_region = pytrends.interest_by_region(resolution=res, inc_low_vol=True, inc_geo_code=False)
        df_region.reset_index(inplace=True)
        df_region_name = "gtrends_region"+str(save_name)+str((i+4)//4)+".csv"
        df_region.to_csv(df_region_name, index = False)
        i += 4

# %%
def normalise(df, n_file, key_ref, col='date'):
    li = []
    # Checking the relative popularity between comparisons
    for i in range(n_file-1):    
        df = df.drop(columns=col+"."+str(i+1)+"")
        # Appending the list if relative popularity of the keyword reference is different
        if df[key_ref+"."+str(i+1)+""][0] == df[key_ref][0]:
            pass
        else:
            li.append(i+1)
    
    # Normalizing relative popularity when the relative popularity of the keyword reference is different         
    for l in li:
        k = df.columns.get_loc(key_ref+"."+str(l)+"")
        for n in range(len(df.index)):
            # Computing relative popularity by normalizing according to the reference
            if df.iloc[n,(k)] > 0:
                for m in range(5):
                    df.iloc[n,(k-4+m)] = (df.iloc[n,(k-4+m)] * (df[key_ref][n]/df.iloc[n,(k)]))
            else:
                for m in range(5):
                    df.iloc[n,(k-4+m)] = (df.iloc[n,(k-4+m)] * (df[key_ref][n]/0.01))
    return df

# %%
def tidy(df, n_file, key_ref, kw_file, col='date'):
    for i in range(n_file-1):    
        df = df.drop(columns=key_ref+"."+str(i+1)+"")
    df=pd.melt(df,id_vars=[col],var_name='Keywords', value_name='RelativePopularity')
    df = df.merge(kw_file, on="Keywords")
    return df

# %% [markdown]
#     kw_list is a list of keywords to search,
#     geo can be set to certain country code, e.g ‘US’, or ‘’ for worldwide,
#     cat can be set to certain category, e.g. All category: 0, Food & Drink: 71,
#     timeframe can be set to past 5 years 'today 5-y', 2004 to present 'all' , etc.

# %% [markdown]
# Interest over time
#
# This will return historical data for when a keyword was searched for the most, over the timeframe you select. This is reflective of what is shown in the 'interest over time' section of Google Trends.

# %% [markdown]
#     resolution - Can be set to CITY, COUNTRY or REGION.
#     inc_low_vol - Either a True or False boolean to determine whether to display data for low volume countries.
#     inc_geo_code - This can also be set to either True or False, depending on whether you want to include ISO codes along with the country names.

# %%
kw_list=["Airpods","Ipad","Iphone","apple watch","apple tv","ipod"]
gtrends_overtime(kw_list, "_worldwide_",
                 category=71, time='all', loc='')

data = pytrends.interest_over_time()
data.to_csv('Py_VS_R.csv', encoding='utf_8_sig')

# %%
import pandas as pd
from pytrends.request import TrendReq
pytrend = TrendReq(hl='en-US', tz=360)
keywords=["Airpods","Ipad","Iphone","apple watch","apple tv","ipod"]
 #= ['Python', 'R']
pytrend.build_payload(
     kw_list=keywords,
     cat=0,
     timeframe='today 3-m',
     geo='TW',
     gprop='')
data = pytrend.interest_over_time()
data= data.drop(labels=['isPartial'],axis='columns')
image = data.plot(title = 'Python V.S. R in last 3 months on Google Trends ')
fig = image.get_figure()
fig.savefig('figure.png')
data.to_csv('Py_VS_R.csv', encoding='utf_8_sig')
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# <ipython-input-7-60f926b79faf> in <module>
#       4 keywords=["Airpods","Ipad","Iphone","apple watch","apple tv","ipod"]
#       5  #= ['Python', 'R']
# ----> 6 pytrend.build_payload(
#       7      kw_list=keywords,
#       8      cat=0,
#
# ~\AppData\Roaming\Python\Python38\site-packages\pytrends\request.py in build_payload(self, kw_list, cat, timeframe, geo, gprop)
#     180         self.token_payload['req'] = json.dumps(self.token_payload['req'])
#     181         # get tokens
# --> 182         self._tokens()
#     183         return
#     184
#
# ~\AppData\Roaming\Python\Python38\site-packages\pytrends\request.py in _tokens(self)
#     186         """Makes request to Google to get API tokens for interest over time, interest by region and related queries"""
#     187         # make the request and parse the returned json
# ...

# %%
gtrends_region(kw_list, 'Noodles', "_worldwide_",
               category=71, time='all', loc='', res='COUNTRY')

# %%
normalised = normalise(combined, n_file=25, key_ref="Noodles", col='date')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3532a748584b> in <module>
# ----> 1 normalised = normalise(combined, n_file=25, key_ref="Noodles", col='date')
#       2
#
# NameError: name 'combined' is not defined

# %%
overtime = tidy(normalised, 25, "Noodles", kw_file, col='date')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-eae584d82926> in <module>
# ----> 1 overtime = tidy(normalised, 25, "Noodles", kw_file, col='date')
#
# NameError: name 'normalised' is not defined

# %%
pytrends1.build_payload(list1,geo='US',timeframe="today 12-m")
pytrends2.build_payload(list2,geo='US',timeframe="today 12-m")#Trending UK 
uk_trending = pytrends.trending_searches(pn='united_kingdom')
uk_trend_df = pd.DataFrame(uk_trending)
uk_trend_df

#Trending US
us_trending = pytrends.trending_searches(pn='united_states')
us_trend_df = pd.DataFrame(us_trending)
us_trend_df

#Trending Japan
india_trending = pytrends.trending_searches(pn='india')
india_trend_df = pd.DataFrame(japan_trending)
india_trend_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3c1c0dd90af1> in <module>
# ----> 1 pytrends1.build_payload(list1,geo='US',timeframe="today 12-m")
#       2 pytrends2.build_payload(list2,geo='US',timeframe="today 12-m")#Trending UK
#       3 uk_trending = pytrends.trending_searches(pn='united_kingdom')
#       4 uk_trend_df = pd.DataFrame(uk_trending)
#       5 uk_trend_df
#
# NameError: name 'pytrends1' is not defined

# %%
list1=["Airpods","Ipod","Ipad", "Iphone","Apple Watch"]
list2=["The office", "Breaking Bad" ,"Money Heist","Peaky Blinders" ,"Black Mirror"]
pytrends1=TrendReq()
pytrends2=TrendReq()
pytrends1.build_payload(list1,geo='US',timeframe="today 12-m")
pytrends2.build_payload(list2,geo='US',timeframe="today 12-m")
df1=pytrends1.interest_over_time()
df2=pytrends2.interest_over_time()
df1
# Out:
#             Airpods  Ipod  Ipad  Iphone  Apple Watch  isPartial
# date
# 2019-11-17       10     1    13      62           10      False
# 2019-11-24       17     2    19      78           20      False
# 2019-12-01       13     2    16      69           14      False
# 2019-12-08       11     2    14      64           11      False
# 2019-12-15       12     2    14      68           12      False
# 2019-12-22       20     2    19      87           21      False
# 2019-12-29       11     2    14      71           12      False
# 2020-01-05       10     2    12      61            9      False
# 2020-01-12        9     1    12      57            8      False
# 2020-01-19        8     1    12      59            8      False
# 2020-01-26        7     1    11      52            7      False
# 2020-02-02        7     1    11      53            7      False
# 2020-02-09        7     1    11      53            7      False
# 2020-02-16        7     1    11      56            7      False
# ...

# %%
averageList1=[]
averageList2=[]
for item in list1:
    averageList1.append(df1[item].mean().round(0))
for item in list2:
    averageList2.append(df2[item].mean().round(0))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-2a23af97fb76> in <module>
#       2 averageList2=[]
#       3 for item in list1:
# ----> 4     averageList1.append(df1[item].mean().round(0))
#       5 for item in list2:
#       6     averageList2.append(df2[item].mean().round(0))
#
# AttributeError: 'float' object has no attribute 'round'
